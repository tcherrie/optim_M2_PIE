# %% [markdown]
# # Exercises
#
# _______

# %% [markdown]
# ## B) Adjoint method

# %% [markdown]
# Consider the following state equation:
#
# $$ \begin{bmatrix}
# 1 & 2x & x^2 \\
# 2x & 2 & x^3 \\
# x^2 & x^3 & 1\\
# \end{bmatrix}
# \begin{bmatrix}
# u_0 \\ u_1 \\ u_2
# \end{bmatrix} - \begin{bmatrix}
# 1 \\ 2 \\ 3
# \end{bmatrix} = 0$$
#
# So that the state $u$ depends implictely on the design variable $x$.
# We are interested in minimizing the following criterion:
#
# $C(u,x) = 3x + |u|^2 $
#
# Current design variable is $x_0=1$.

# %% [markdown]
# 1. Compute $u(x_0)$ and $C(u_0, x_0)$.

# %%
from scipy.linalg import solve
from numpy import array

def K(x):
    "Matrix of the state equation"
    return array(...)

rhs = array([...]) # right hand side of the state equation

x0 = 1
u0 = solve(K(x0), rhs)
print(u0)

from numpy.linalg import norm
def C(u,x):
    "criteria"
    return ...

C0 = C(u0, x0)
print(f"{C0 = :.2f}")

# %% [markdown]
# 2. Compute $\partial_u S(x_0)$

# %%
def partial_S_partial_u(x):
    "Partial derivative of the state equation w.r.t u"
    return ...

print(partial_S_partial_u(x0))

# %% [markdown]
# 3. Formulate and solve the adjoint problem.

# %%
def partial_C_partial_u(u):
    "Partial derivative of the criteria w.r.t u"
    return ...

p0 = solve(..., ...)  # Adjoint problem

print(p0)

# %% [markdown]
# 4. Compute the total derivative of $C$ with respect to $x$

# %%
partial_C_partial_x = 3

def partial_S_partial_x(x, u):
    "Partial derivative of the state equation w.r.t x"
    u = u[:,0]
    return array([...])  #

def dC_dx(u, p, x):
    "total derivative of the criteria"
    return ...  

print(dC_dx(u0, p0, x0))

# %% [markdown]
# 5. Check your result with finite differences.

# %%
h = 1e-6
dC_dx_FD = ...   # finite difference approximation
print(dC_dx_FD)
