# %% [markdown]
# # Exercise - Constrained optimization
#
# _______

# %% [markdown]
# A preliminary analysis of the electric actuation market made it possible to model the cost of an electric actuator of a given power—based on its mass $m$ and efficiency $\eta$ using the following simplified function:
#
# $$C(m,\eta) = \alpha \frac{\eta}{m+1} + \beta m,$$
#
# with $\alpha = 150~ €\cdot kg$, $\beta = 100 ~€ / kg$. The aim is to predetermine the mass and efficiency of the least expensive possible actuator, while satisfying a maximum temperature constraint expressed as follows:
# $$ T(m, \eta) = \frac{\gamma}{(\eta -0.5)m} \leq T_{\max},$$
#
# with $\gamma = 10~K \cdot kg^2$, $T_{\max} = 125 °C$. We denote $x=[m, \eta]^T$ the vector of optimization variables.

# %% [markdown]
# 1. Write the optimization problem $\mathcal P$ in standard form. The constraint function $G(x)$ should be normalized.

# %%
alpha = 150
beta = 100
gamma = 10
Tmax = 125


def G(x):
    """ normalized inequality constraint """
    m, eta = x
    return ....

# %% [markdown]
# We reformulate $\mathcal P$ as an unconstrained problem $\tilde{\mathcal P}$, consisting in minimizing the penalized objective function:
#
# $$ F(x) = C(x) + \frac{1}{2 \epsilon} \max(G(x),0)^2, $$
#
# with $\epsilon>0$ a real number that can be arbitrarily small. We assume that $\epsilon=1$ in what follows.
#
# 2. Compute $\mathrm{d}_x F$.

# %% [markdown]
# 3. Implement an adaptative-step gradient descent and solve the problem. Comments.

# %% [markdown]
# Now, we come back to the original constrained optimization problem $\mathcal P$, that we want to solve with a dual method.

# %% [markdown]
# 4. Plot the isolines of $C(x)$ and $G(x)$. Determine graphically the solution of the problem.

# %% [markdown]
# 5. Write the Lagrangian $\mathcal L(x, \lambda)$ associated with $\mathcal P$. What is $\nabla \mathcal L$ at the optimal point $(x^*, \lambda^*)$? Deduce a nonlinear system that should be solved to get the optimal solution.

# %% [markdown]
# 6. The optimal solution is a saddle point of $\mathcal L$. Justify that a Newton algorithm can be used to find the saddle point.

# %% [markdown]
# 7. Implement the Newton method and solve the problem.
