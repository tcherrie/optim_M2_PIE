# %% [markdown]
# # Exercises
#
# ## A) Estimate derivative with finite differences and complex step
#
# _______

# %% [markdown]
# We consider the following real valued functions :
#
# - $f_1 = 1 + x + x^2 - x^3$
# - $f_2 = x + x^2 - x^3$
# - $f_3 = \sqrt{(1 + x)^2}$
# - $f_4 = |1+x|$

# %%
def f1(x):
    return 1 + x + x**2 - x**3

def f2(x):
    return x + x**2 - x**3

def f3(x):
    return ((1 + x)**2) ** 0.5

def f4(x):
    return abs(1+x)

# %% [markdown]
# ### Questions
#
# 1. Plot the graphs of the functions for $x\in [-1,1]$.

# %%
import matplotlib.pyplot as plt
from numpy import linspace

x = linspace(-1,1,100)
plt.plot(x, f1(x), label = "f1")
...
plt.legend(); plt.grid()
plt.show()

# %% [markdown]
# 2. Compute the reference derivatives.

# %%
def df1_dx(x):
    return ...

def df2_dx(x):
    return ...

def df3_dx(x):
    return ...

def df4_dx(x):
    return ...

# %% [markdown]
# 3. For $h\in [10^{-16}, 1]$ and each of the functions, plot the log-scale error of the approximated derivative at $x=0$ using the following techniques:
# - a) Forward finite difference `FD1`
# - b) Centered finite difference `FD2`
# - c) Complex step `CS`

# %%
def ffd(f, x, h):
    "Forward finite differences"
    return ...

def cfd(f, x, h):
    "Centered finite differences"
    return ...

def cplxStep(f, x, h):
    "Complex step"
    return ...

# %%
# Plots
from numpy import logspace
h = logspace(-16, -1, 100)
x0 = 0
plt.loglog(h, abs(ffd(f1, x0, h) - df1_dx(x0)))
...
plt.loglog(h, h, '--', label = "$h$")
plt.loglog(h, h**2, '--', label = "$h^2$")
plt.legend(); plt.title("Derivative error for f1 at x=0")
plt.show()

# %% [markdown]
# 4. Interpret the results.
